# %%
import numpy as np

import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from torchvision import transforms as T
from torchvision.datasets import CIFAR10
from torch.utils.data import Dataset, DataLoader

# %%
CIFAR10_MEAN, CIFAR10_STD = (0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)

train_transforms = T.Compose([
    T.RandomCrop(32, padding=4),
    T.RandomHorizontalFlip(),
    T.ToTensor(),
    T.Normalize(mean=CIFAR10_MEAN, std=CIFAR10_STD)
])

val_transforms = T.Compose([
    T.ToTensor(),
    T.Normalize(mean=CIFAR10_MEAN, std=CIFAR10_STD)
])

# %%
TRAIN_BATCH_SIZE = 64
VAL_BATCH_SIZE = 250

train_dataset = CIFAR10(root='./data', train=True, download=True, transform=train_transforms)
train_loader = DataLoader(train_dataset, batch_size=TRAIN_BATCH_SIZE, shuffle=True, num_workers=1)

val_dataset = CIFAR10(root='./data', train=False, download=True, transform=val_transforms)
val_loader = DataLoader(val_dataset, batch_size=VAL_BATCH_SIZE, shuffle=False, num_workers=1)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
from src.engine import train
from src.groups import P4, P4m
from experiments.CIFAR10 import ResNet, GResNet

# %% [markdown]
# ### Non-equivariant architecture
# ---

# %%
block_kwargs = [
    {"num_blocks" : 3, "out_channels" : 16, "stride" : 2},
    {"num_blocks" : 3, "out_channels" : 32, "stride" : 2},
    {"num_blocks" : 3, "out_channels" : 64, "stride" : 2}
]

model = ResNet(
    num_classes=10, 
    block_kwargs=block_kwargs,
    img_channels=3,
    in_channels=16
)

print(f"Model has {sum(param.numel() for param in model.parameters())} parameters")
# Out:
# Model has 272762 parameters

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

model = model.to(device)
criterion = nn.CrossEntropyLoss()

optimizer = torch.optim.SGD(model.parameters(), lr=0.05, momentum=0.95)
scheduler = torch.optim.lr_scheduler.MultiStepLR(optimizer, milestones=[30, 40], gamma=0.2)

# %%
NUM_EPOCHS = 50

history = train(
    model,
    dataloaders={"train" : train_loader, "val" : val_loader},
    criterion=criterion,
    optimizer=optimizer,
    scheduler=scheduler,
    num_epochs=NUM_EPOCHS, 
    device='cuda'
)
# Out:
# Epoch 0/49
# ----------
# train Loss: 1.7589 Acc: 0.3413
#   val Loss: 1.4006 Acc: 0.4874
# Epoch 1/49
# ----------
# train Loss: 1.3086 Acc: 0.5251
#   val Loss: 1.2827 Acc: 0.5596
# Epoch 2/49
# ----------
# train Loss: 1.0912 Acc: 0.6102
#   val Loss: 1.0531 Acc: 0.6295
# Epoch 3/49
# ----------
# train Loss: 0.9676 Acc: 0.6586
#   val Loss: 0.9361 Acc: 0.6728
# Epoch 4/49
# ----------
# train Loss: 0.8734 Acc: 0.6917
#   val Loss: 0.8703 Acc: 0.6980
# Epoch 5/49
# ----------
# train Loss: 0.8057 Acc: 0.7183
#   val Loss: 0.8827 Acc: 0.6937
# Epoch 6/49
# ----------
# train Loss: 0.7527 Acc: 0.7364
#   val Loss: 0.7690 Acc: 0.7410
# Epoch 7/49
# ----------
# train Loss: 0.7078 Acc: 0.7523
#   val Loss: 0.6991 Acc: 0.7608
# Epoch 8/49
# ----------
# train Loss: 0.6657 Acc: 0.7665
#   val Loss: 0.6896 Acc: 0.7604
# Epoch 9/49
# ----------
# train Loss: 0.6382 Acc: 0.7783
#   val Loss: 0.6350 Acc: 0.7820
# Epoch 10/49
# ----------
# train Loss: 0.6090 Acc: 0.7889
#   val Loss: 0.6179 Acc: 0.7901
# Epoch 11/49
# ----------
# Epoch 39/49
# ----------
# train Loss: 0.3429 Acc: 0.8795
#   val Loss: 0.4537 Acc: 0.8499
# Epoch 40/49
# ----------
# train Loss: 0.3390 Acc: 0.8804
#   val Loss: 0.4518 Acc: 0.8520
# Epoch 41/49
# ----------
# train Loss: 0.3412 Acc: 0.8811
#   val Loss: 0.4570 Acc: 0.8500
# Epoch 42/49
# ----------
# train Loss: 0.3362 Acc: 0.8833
#   val Loss: 0.4583 Acc: 0.8520
# Epoch 43/49
# ----------
# train Loss: 0.3367 Acc: 0.8818
#   val Loss: 0.4527 Acc: 0.8529
# Epoch 44/49
# ----------
# train Loss: 0.3334 Acc: 0.8827
#   val Loss: 0.4544 Acc: 0.8535
# Epoch 45/49
# ----------
# train Loss: 0.3352 Acc: 0.8824
#   val Loss: 0.4521 Acc: 0.8545
# Epoch 46/49
# ----------
# train Loss: 0.3303 Acc: 0.8832
#   val Loss: 0.4529 Acc: 0.8533
# Epoch 47/49
# ----------
# train Loss: 0.3314 Acc: 0.8835
#   val Loss: 0.4508 Acc: 0.8544
# Epoch 48/49
# ----------
# train Loss: 0.3299 Acc: 0.8833
#   val Loss: 0.4484 Acc: 0.8550
# Epoch 49/49
# ----------
# train Loss: 0.3297 Acc: 0.8828
#   val Loss: 0.4540 Acc: 0.8546

# %% [markdown]
# ### Equivariant architecture
# ---

# %%
block_kwargs = [
    {"num_blocks" : 3, "out_channels" : 6, "stride" : 2},
    {"num_blocks" : 3, "out_channels" : 12, "stride" : 2},
    {"num_blocks" : 3, "out_channels" : 24, "stride" : 2}
]

model = GResNet(
    group = P4m,
    num_classes=10, 
    block_kwargs=block_kwargs,
    img_channels=3,
    in_channels=6
)

print(f"Model has {sum(param.numel() for param in model.parameters())} parameters")
# Out:
# Model has 302080 parameters

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

model = model.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=2e-3)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=100, eta_min=1e-5)

# %%
NUM_EPOCHS = 50

history = train(
    model,
    dataloaders={"train" : train_loader, "val" : val_loader},
    criterion=criterion,
    optimizer=optimizer,
    scheduler=scheduler,
    num_epochs=NUM_EPOCHS, 
    device='cuda'
)
# Out:
# Epoch 0/49
# ----------
# /trinity/home/d.kuznedelev/.conda/envs/deep_leaning/lib/python3.9/site-packages/torch/nn/functional.py:3454: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   warnings.warn(
# train Loss: 1.7122 Acc: 0.3539
#   val Loss: 1.5372 Acc: 0.4338
# Epoch 1/49
# ----------
# train Loss: 1.3592 Acc: 0.5003
#   val Loss: 1.4672 Acc: 0.4897
# Epoch 2/49
# ----------
# train Loss: 1.1659 Acc: 0.5797
#   val Loss: 1.2072 Acc: 0.5736
# Epoch 3/49
# ----------
# train Loss: 1.0335 Acc: 0.6328
#   val Loss: 1.0988 Acc: 0.5946
# Epoch 4/49
# ----------
# train Loss: 0.9546 Acc: 0.6609
#   val Loss: 0.9992 Acc: 0.6414
# Epoch 5/49
# ----------
# train Loss: 0.8996 Acc: 0.6815
#   val Loss: 0.9008 Acc: 0.6776
# Epoch 6/49
# ----------
# train Loss: 0.8424 Acc: 0.7041
#   val Loss: 1.0829 Acc: 0.6191
# Epoch 7/49
# ----------
# train Loss: 0.8078 Acc: 0.7171
#   val Loss: 0.8181 Acc: 0.7093
# Epoch 8/49
# ----------
# train Loss: 0.7712 Acc: 0.7283
#   val Loss: 0.8232 Acc: 0.7141
# Epoch 9/49
# ----------
# train Loss: 0.7478 Acc: 0.7384
#   val Loss: 0.8379 Acc: 0.7121
# Epoch 10/49
# ----------
# train Loss: 0.7143 Acc: 0.7486
#   val Loss: 0.8844 Acc: 0.6942
# Epoch 11/49
# ----------
# train Loss: 0.6967 Acc: 0.7551
#   val Loss: 0.7231 Acc: 0.7453
# Epoch 12/49
# ----------
# train Loss: 0.6719 Acc: 0.7620
#   val Loss: 0.7586 Acc: 0.7346
# Epoch 13/49
# ----------
# train Loss: 0.6503 Acc: 0.7704
#   val Loss: 0.7173 Acc: 0.7537
# Epoch 14/49
# ----------
# train Loss: 0.6370 Acc: 0.7745
#   val Loss: 0.7130 Acc: 0.7580
# Epoch 15/49
# ----------
# train Loss: 0.6135 Acc: 0.7844
#   val Loss: 0.8184 Acc: 0.7244
# Epoch 16/49
# ----------
# train Loss: 0.5986 Acc: 0.7906
#   val Loss: 0.7143 Acc: 0.7544
# Epoch 17/49
# ----------
# train Loss: 0.5846 Acc: 0.7931
#   val Loss: 0.6811 Acc: 0.7709
# Epoch 18/49
# ----------
# train Loss: 0.5685 Acc: 0.8002
#   val Loss: 0.6303 Acc: 0.7812
# Epoch 19/49
# ----------
# train Loss: 0.5558 Acc: 0.8037
#   val Loss: 0.6767 Acc: 0.7681
# Epoch 20/49
# ----------
# train Loss: 0.5409 Acc: 0.8093
#   val Loss: 0.7572 Acc: 0.7464
# Epoch 21/49
# ----------
# train Loss: 0.5282 Acc: 0.8138
#   val Loss: 0.6381 Acc: 0.7825
# Epoch 22/49
# ----------
# train Loss: 0.5170 Acc: 0.8163
#   val Loss: 0.6613 Acc: 0.7764
# Epoch 23/49
# ----------
# train Loss: 0.5043 Acc: 0.8205
#   val Loss: 0.6242 Acc: 0.7887
# Epoch 24/49
# ----------
# train Loss: 0.4950 Acc: 0.8256
#   val Loss: 0.6095 Acc: 0.7937
# Epoch 25/49
# ----------
# train Loss: 0.4839 Acc: 0.8288
#   val Loss: 0.6136 Acc: 0.7963
# Epoch 26/49
# ----------
# train Loss: 0.4698 Acc: 0.8336
#   val Loss: 0.6224 Acc: 0.7973
# Epoch 27/49
# ----------
# train Loss: 0.4561 Acc: 0.8381
#   val Loss: 0.6084 Acc: 0.7915
# Epoch 28/49
# ----------
# train Loss: 0.4486 Acc: 0.8410
#   val Loss: 0.6084 Acc: 0.7965
# Epoch 29/49
# ----------
# train Loss: 0.4408 Acc: 0.8438
#   val Loss: 0.5989 Acc: 0.7996
# Epoch 30/49
# ----------
# train Loss: 0.4259 Acc: 0.8482
#   val Loss: 0.5815 Acc: 0.8055
# Epoch 31/49
# ----------
# train Loss: 0.4196 Acc: 0.8505
#   val Loss: 0.6285 Acc: 0.7922
# Epoch 32/49
# ----------
# train Loss: 0.4121 Acc: 0.8533
#   val Loss: 0.5876 Acc: 0.8028
# Epoch 33/49
# ----------
# train Loss: 0.4006 Acc: 0.8580
#   val Loss: 0.6076 Acc: 0.8004
# Epoch 34/49
# ----------
# train Loss: 0.3965 Acc: 0.8590
#   val Loss: 0.5781 Acc: 0.8114
# Epoch 35/49
# ----------
# train Loss: 0.3869 Acc: 0.8620
#   val Loss: 0.5734 Acc: 0.8119
# Epoch 36/49
# ----------
